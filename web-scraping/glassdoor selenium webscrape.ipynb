# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome()
driver.get("https://www.glassdoor.com")
assert "Glassdoor" in driver.title

# %%
def google_login():
    g_login = driver.find_element_by_xpath('//*[@id="InlineLoginModule"]/div/div/div/div/div/div[2]/div/div[2]/button')
    g_login.click()
    parent_handle = driver.current_window_handle
    handles = driver.window_handles
    driver.switch_to_window(handles[1])
    
    wait = WebDriverWait(driver, 4)
    
    email_field = driver.find_element_by_xpath('//*[@id="identifierId"]')
    email = '
    email_field.send_keys(email)
    driver.find_element_by_id('identifierNext').click()
    
    wait = WebDriverWait(driver, 4)
    pw = 'Wonton123.'
    driver.find_element_by_xpath('//*[@id="password"]/div[1]/div/div[1]/input').send_keys(pw)
    driver.find_element_by_id('passwordNext').click()

# %%
google_login()
# Out:
# /home/zeema/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: use driver.switch_to.window instead
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-83-2f2439d8223d> in <module>
# ----> 1 google_login()
#
# <ipython-input-82-2403e28dc561> in google_login()
#       8     wait = WebDriverWait(driver, 4)
#       9
# ---> 10     email_field = driver.find_element_by_xpath('//*[@id="identifierId"]')
#      11     email = 'liyingchengcathy@gmail.com'
#      12     email_field.send_keys(email)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="identifierId"]"}
#   (Session info: chrome=74.0.3729.169)
#   (Driver info: chromedriver=74.0.3729.6 (255758eccf3d244491b8a1317aa76e1ce10d57e9-refs/branch-heads/3729@{#29}),platform=Linux 4.15.0-48-generic x86_64)

# %%
len(handles)
driver.switch_to_window(handles[0])

# %%
# enter keyword
job_title = 'data engineer'
driver.find_element_by_id('sc.keyword').send_keys(job_title)

# %%
location = 'New york, NY '
driver.find_element_by_id('sc.location').send_keys(location)

# %%
driver.find_element_by_id('HeroSearchButton').click()

# %%
# a = driver.find_elements_by_class_name('filter')

# %%
from bs4 import BeautifulSoup
h = driver.page_source

# %%
soup = BeautifulSoup(h, 'html.parser')
print(soup)
# Out:
# <html class="flex" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/"><head><title>Data engineer Jobs in New York, NY | Glassdoor</title><link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/><link href="/favicon.ico" rel="icon" type="image/x-icon"/><meta content="origin" name="referrer"/><meta content="width=device-width" name="viewport"/><meta content="#0caa41" name="theme-color"/><!-- Windows Phone --><meta content="#0caa41" name="msapplication-navbutton-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="#0caa41" name="apple-mobile-web-app-status-bar-style"/><link href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-57.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b" rel="apple-touch-icon-precomposed"/><link href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-72.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-114.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b" rel="apple-touch-icon-precomposed" sizes="114x114"/><link href="https://www.glassdoor.com/jobs-ux-app/static/img/mobile/icons/touch-icon-144.png?v=d6f1464ffdffe602a47f344b37f7baaa5c65d72b" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="/manifest.json" rel="manifest"/><meta content="Search Data engineer jobs in New York, NY with company ratings &amp; salaries. 4,873 open jobs for Data engineer in New York." name="description"/><!-- SL:start:norewrite --><meta content="589698942" property="al:ios:app_store_id"/><meta content="Glassdoor" property="al:ios:app_name"/><link href="https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm" rel="canonical"/><!-- SL:end:norewrite --><meta content="At9LpmW/SGKoQafqVaHTfeX5N9lRrOEZw0dAoUrKiO21CAbclpg0c0XecEzX5QigJaDNvdHGhDU8tDKRRduS6AYAAABmeyJvcmlnaW4iOiJodHRwczovL2dsYXNzZG9vci5jb206NDQzIiwiZmVhdHVyZSI6Ikluc3RhbGxlZEFwcCIsImV4cGlyeSI6MTUxNDI1NjE5NCwiaXNTdWJkb21haW4iOnRydWV9" data-expires="2017-12-26" data-feature="getInstalledRelatedApps" http-equiv="origin-trial"/><meta content="no-cache,must-revalidate" http-equiv="Cache-Control"/><meta content="no-cache" http-equiv="Pragma"/><meta content="0" http-equiv="Expires"/><meta content="Data engineer Jobs in New York, NY" property="og:title"/><meta content="website" property="og:type"/><meta content="Glassdoor" property="og:site_name"/><meta content="129253937150340" property="fb:app_id"/><meta content="https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm" property="og:url"/><meta content="https://www.glassdoor.com/jobs-ux-app/static/img/partners/fb/logo-1200x630.png?v=721f9cswl" property="og:image"/><meta content="Search Data engineer jobs in New York, NY with company ratings &amp; salaries. 4,873 open jobs for Data engineer in New York." property="og:description"/><link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet"/><link href="https://www.glassdoor.com/jobs-ux-app/static/css/gd-job-search-core.css?v=0a1a0edqtx" media="all" rel="stylesheet" type="text/css"/><!-- because the getter clears the value --><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://sb.scorecardresearch.com/c2/18019367/cs.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><scrip ...
# 	window.gdGlobals = window.gdGlobals ||
# 		[{
# 			'analyticsId':                      "UA-2595786-1",
#
#
# 			'analyticsUrl':                     "/search/jobs",
#
# 			'deferredScriptType':               "text/x-deferred-js",
# 			'accessDeniedRedirectUrl':          '',
# 			'locale': 							'en-US',
# 			'env': 'prod',
#
#
# 			'device':       {
#
#
# 								'handheld':     false,
#
#
# 								'tablet':       	false,
# 								'deviceTypeId': 	1,
# 								'platformTypeId': 	3,
# 								'viewTypeId': 		4
# 							},
# 			'page':         {
#
# 								'domain':       "www.glassdoor.com",
# 								'domainId':		1,
#
#
# 								'domainSuffix': "",
#
#
# 								'group':        "Search-Jobs",
#
#
# 								'guid':         '0000016afc6dd3d388edeefbcce1a35c',
#
#
# 								'flex':         true,
#
#
# 								'section':      "search",
#
#
# 								'type':         "search:jobs:job-search-lite",
#
#
# 								'id':           "search:jobs:job-search-lite",
#
# 								'med': '',
#
# 								'src' : '',
# 								'content' : '',
# 								'campaign' : '',
# 								'term' : '',
# 								'state' : 'open',
# 								'untranslatedUrl' : 'https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm'
#
# 							},
# 			'user':         {
#
# 								'guid':         'ebe429b6-dc73-4fa2-9fcf-42959cf11699',
#
#
# 									'id': "97276988",
# 									'membershipType': "BASIC",
# 									'age' : "",
# 									'gender' : "UNKNOWN",
# 									'education' : "",
# 									'regDate' : '20190527',
# 									'regMonth' : 'May',
#
# 								'ipAddr':       "98.113.182.93",
#
#
# 								'locale':       "en_US",
#
#
# 								'country':      "US",
# 								'ipLocationId': "1132219",
# 								'ipLocationType': "C",
#
# 								'elligibleForAppBoy': false
# 							},
# 			'vendor':       {
# 								'fbReqPerms':   ""
# 							},
#
# 				'implicitLoc':'New York, NY',
#
# 			'search':       {
#
# 				"rawKeyword":"data engineer"
#
# 								, 'location': "New York",
# 								'locationType': "C",
# 								'locationId': "1132348"
#
# 								, 'occupation' : "data engineer"
#
# 								, 'totalSearchResults': "4873",
# 								'displayedSearchResults': "29",
# 								'pageNumber': "1",
# 								'noData' : 'false'
#
# 									, 'jobIds':[
#
# 												'3089502227'
#
# 													,
#
# 												'3148048922'
#
# 													,
#
# 												'3152137674'
#
# 													,
#
# 												'1418576186'
#
# 													,
#
# 												'2805741309'
#
# 													,
#
# 												'3180856712'
#
# 													,
#
# 												'3232013968'
#
# 													,
#
# 												'3030464918'
#
# 													,
#
# 												'3054562783'
#
# 													,
#
# 												'3236461601'
#
# 													,
#
# 												'3245029582'
#
# 													,
#
# 												'3203985078'
#
# 													,
#
# 												'3138265581'
#
# 													,
#
# 												'3219501803'
#
# 													,
#
# 												'3129502181'
#
# 													,
#
# 												'3097417370'
#
# 													,
#
# 												'3036892268'
#
# 													,
#
# 												'3244321284'
#
# 													,
#
# 												'3097422861'
#
# 													,
#
# 												'3232013963'
#
# 													,
#
# 												'3227341585'
#
# 													,
#
# 												'3157564256'
#
# 													,
#
# 												'3225996706'
#
# 													,
#
# 												'3095809110'
#
# 													,
#
# 												'3098247873'
#
# 													,
#
# 												'3153139251'
#
# 													,
#
# 												'3042963953'
#
# 													,
#
# 												'2726367346'
#
# 									]
#
# 							, 'segmentType' : "OL"
#
# 			},
# 			'employer' : {
#
# 			},
# 			'job' : {
#
# 			},
# 			'test' : {
#
# 				'planoutIdList': [
#
# 						, "jobViewDomain.exp_jobViewDomain_catchall"
#
# 						, "jobAlertDomain.2018_01_28_exp_fja"
#
# 						, "savedJobsDomain.non_user_saved_jobs_catchall"
#
# 						, "urgency.2018_10_15_badgeDiversity"
#
# 						, "easyApplyDomain.exp_easyApplyDomain_catchall"
#
# 						, "easyApplyDomain.2018_09_20_exp_eaConfirmV2"
#
# 						, "jobViewDomain.2019_03_20_indeedApply"
#
# 						, "jobDetailsDomain.exp_jobDetailsDomain_catchall"
#
# 						, "serpDomain.exp_serpDomain_catchall"
#
# 						, "myJobsDomain.exp_myJobsDomain_catchall"
#
# 						, "myJobsDomain.2018_09_06_myJobsJAFilters"
#
# 						, "urgency.urgency_catchall"
#
# 						, "myJobsDomain.03-22-2019_newJobsHome"
#
# 						, "jxGlobalDomain.exp_jxGlobalDomain_catchall"
#
# 						, "jx_global.2018_06_25_xToSerpUrgencyBadge"
#
# 						, "serpDomain.2019_05_20_newJobListings"
#
# 						, "serpDomain.expSgocVsGoc_2019_05_20"
#
# 						, "jobViewDomain.2018_11_16_laf_jan"
#
# 						, "jobViewDomain.2018_10_05_laf_googlejobs"
#
# 						, "jobs-ux-dk-2.redirectToHome"
#
# 						, "serp_sw.2018_09_12_sw"
#
# 						, "jobAlertDomain.exp_jobAlertDomain_catchAll"
#
# 						, "jobDetailsDomain.05-20-2019_serp_ctaLayout"
#
# 				],
# 				'planoutTreatmentList': [
#
# 						, "jobViewDomainDefaultTreatment"
#
# 						, "fja_on"
#
# 						, "savedJobsDefaultTreatment"
#
# 						, "badges_sevenByTwo"
#
# 						, "easyApplyDefaultTreatment"
#
# 						, "ea_confirm_on"
#
# 						, "indeedApply_on"
#
# 						, "jobDetailsDefaultTreatment"
#
# 						, "serpDefaultTreatment"
#
# 						, "myJobsDefaultTreatment"
#
# 						, "myJobsJAFilters_on"
#
# 						, "urgency_default"
#
# 						, "newJobsHome_on"
#
# 						, "jxGlobalDefaultTreatment"
#
# 						, "xToSerpUrgencyBadge_off"
#
# 						, "newJobListings_off"
#
# 						, "gocTreatment"
#
# 						, "laf_jan_on"
#
# 						, "laf_googlejobs_on"
#
# 						, "savedJobsRedirect-false"
#
# 						, "sw_on"
#
# 						, "jobAlertDefaultTreatment"
#
# 						, "ctaLayout_on"
#
# 				]
# 			},
# 			'staticList' : {
#
# 			}
#
#                 ,'jobs-serp' : {
#                     'view': 'search:jobs:job-search-lite',
# 					'jobPreLoaded': false
#                 }
#
# 		}];
#
#
# 	window.getGdGlobals = window.getGdGlobals ||
# 			function() {
# 				return gdGlobals[0];
# 			};
#
# 	GD = window.GD || {};
# 	GD.pageInfo = GD.pageInfo || {};
# 	GD.pageInfo.pageGroup = getGdGlobals().page.group;
# 	GD.domain = getGdGlobals().page.domain;
#
# 	</script><!-- Google Tag Manager --><noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PST2JZ" style="display:none;visibility:hidden" width="0"></iframe></noscript><script>
#
# 			(function(w,d,s,l,i) {
# 				w[l] = w[l] || [];
# 				w[l].push({
# 					'gtm.start': new Date().getTime(),
# 					event:       'gtm.js'
# 				});
# 				var f = d.getElementsByTagName(s)[0],
# 						j = d.createElement(s),
# 						dl = l != 'dataLayer' ? '&l=' + l : '';
# 				j.defer=true;
# 				j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;
# 				f.parentNode.insertBefore(j,f);
# 			})(window,document,'script','gdGlobals','GTM-PST2JZ');
# 		</script><!-- End Google Tag Manager --><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js"></script><script defer="" src="https://unpkg.com/react@16.3.2/umd/react.production.min.js"></script><script defer="" src="https://unpkg.com/react-dom@16.3.2/umd/react-dom.production.min.js"></script><script defer="" src="https://unpkg.com/prop-types@15.6.2/prop-types.min.js"></script><script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js"></script><script>
# try {
# !function(){return function e(o,t,a){function r(s,i){if(!t[s]){if(!o[s]){var l="function"==typeof require&&require;if(!i&&l)return l(s,!0);if(n)return n(s,!0);var d=new Error("Cannot find module '"+s+"'");throw d.code="MODULE_NOT_FOUND",d}var u=t[s]={exports:{}};o[s][0].call(u.exports,function(e){return r(o[s][1][e]||e)},u,u.exports,e,o,t,a)}return t[s].exports}for(var n="function"==typeof require&&require,s=0;s<a.length;s++)r(a[s]);return r}}()({1:[function(e,o,t){e("./lib/index"),e("./lib/bundles/core"),e("./lib/bundles/coreAdaptation"),e("./lib/globalize/cultures/globalize.culture.en-US"),e("./lib/bundles/modules/userLogin/userLogin")},{"./lib/bundles/core":2,"./lib/bundles/coreAdaptation":3,"./lib/bundles/modules/userLogin/userLogin":9,"./lib/globalize/cultures/globalize.culture.en-US":10,"./lib/index":12}],2:[function(e,o,t){GD.i18n.addMsgBundle({salaries:"salaries",reviews:"reviews",interviews:"interviews",companies:"companies",jobs:"jobs",jobTitles:"job titles",in:"in",resume:"resume",edit:"edit",back:"Back",seconds:"seconds",minutes:"minutes",moreThan:"more than",lessThan:"less than",other:"other",msgGenericReadMore:"Read More",msgGo:"Go",msgGoTo:"Go to [str]",msgDownload:"Download",msgLoadingAnim:"Go",unsupportedBrowserLogin:"You're using an old browser. Please consider upgrading. Redirecting you to a secure login page...",msgDone:"Done",msgNext:"Next",msgNotEnoughData:"Not enough data",msgDocLoadPromoAlertText:"This page works faster when you get the Glassdoor app",msgGenericUnexpected:"An unexpected error occurred.",msgGenericUnexpectedTryAgain:"An unexpected error occurred. Please try again.",msgGenericNoThanks:"No Thanks",msgGenericYes:"Yes",msgGenericNo:"No",msgGenericChoose:"Choose",msgGenericThankYou:"Thank You",msgGenericCompleteAllQuestionsError:"Please complete ([numOfErrors]) mandatory questions below",msgGenericSelectOneOptionError:"Select one option",msgGenericImproveDataQualityServices:"Your feedback will be combined with the feedback of others and factored into our data quality efforts.",msgGenericCongratulations:"Congratulations",msgGenericTheElse:"The Else",msgGenericTo:"To",msgGenericOf:"of",msgSmallWords:"a|an|and|as|at|but|by|en|for|if|in|nor|of|on|or|per|the|to|vs?\\.?|via",msgDurationPastMinutesAbbrev:"[num]m",msgDurationPastLastHour:"in the last hour",msgDurationPastHoursAgo:"[num] hours ago",msgDurationPastHoursAbbrev:"[num]h",msgDurationPastToday:"today",msgDurationPastYesterday:"yesterday",msgDurationPast2DaysAgo:"the day before yesterday",msgDurationPastDaysAgo:"[num] days ago",msgDurationPastDay:"[num] day ago",msgDurationPastDaysAbbrev:"[num]d",msgDurationPastDaysPlusAbbrev:"[num]d+",msgDurationPastWeek:"in the last week",msgDurationPast2Weeks:"in the last 2 weeks",msgDurationPastMonth:"in the last month",msgDurationPastWeeksAgo:"[num] weeks ago",msgDurationPastMonthsAgo:"[num] months ago",msgDurationPastMonthsAbbrev:"[num]mo",msgDurationPast6MonthsAgo:"more than 6 months ago",msgDurationPast6Months:"more than 6 months",msgPost:"Post",msgPosted:"Posted",msgExpired:"Expired",savedJobsPlural:"[num] Saved Jobs",savedJobsSingular:"[num] Saved Job",savedJobsNoCount:"Saved Jobs",btnLabelSaved:"Saved",btnLabelUnsave:"Unsave",siteSearchLocPlaceholder:"Location",siteSearchKeywordPlaceholder:"Job Title, Keywords, or Company",search:"Search",employerLogo:"[emp] Logo",msgHelpfulThanks:"Thanks!",msgHelpfulFail:"Something went wrong while recording your vote.  Please try again later.",btnCropThis:"Crop This!",btnCropShowOrig:"Show Original",txtCroppedNowSave:"Cropped. Please save!",errSelectCropArea:"Please select a crop area before you close. Press 'Cancel Cropping' to skip cropping.",txtCropMinSize:"(Min: [cropMinWidth]x[cropMinHeight])",errCropImgTooSmall:"This image is smaller than the minimum crop size. Please cancel cropping.",msgChangeTrackUndo:"You have made changes on this page.\n\nDo you want to undo these changes?\n ",msgChangeTrackAbandon:"You have made changes on this page.\n\nDo you want t ...
#
# }
#  catch (e) {
# var log=window.console?window.console.log:function(o){alert(o)};
# log('Error with inline script "/gd-jx-core-top-en-US.js": ' + e);
# }
# </script><script defer="" src="https://www.glassdoor.com/jobs-ux-app/static/js/gd-jx-core-bottom-en-US.js?v=7ddf515i4w"></script><link href="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-footer.bundle.css?v=7d3f1fl55" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-apply.bundle.css?v=7fac07ow1" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-filterSuggestions.bundle.css?v=cf71a52gf" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-new-user-onboarding.bundle.css?v=101721g2j" rel="stylesheet" type="text/css"/><link href="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-toastService.bundle.css" rel="stylesheet" type="text/css"/><style data-emotion="css"></style><style data-emotion="css"></style><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013221144&amp;cv=9&amp;fst=1559013221144&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><style type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#1d3c78;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_button{text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidde ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}</style><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013227638&amp;cv=9&amp;fst=1559013227638&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013230084&amp;cv=9&amp;fst=1559013230084&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013230749&amp;cv=9&amp;fst=1559013230749&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013232677&amp;cv=9&amp;fst=1559013232677&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/952874112/?random=1559013747870&amp;cv=9&amp;fst=1559013747870&amp;num=1&amp;value=0&amp;currency_code=USD&amp;label=1mEUCIyb5G0QgOmuxgM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1053&amp;u_aw=1920&amp;u_cd=24&amp;u_his=5&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg5f2&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;ref=https%3A%2F%2Fwww.glassdoor.com%2F&amp;tiba=Data%20engineer%20Jobs%20in%20New%20York%2C%20NY%20%7C%20Glassdoor&amp;bttype=purchase&amp;as ...
#         #MainCol ul.jlGrid li a{
#             pointer-events: none;
#         }
#     </style><div class="" id="JobSearch"><div class="noPad"><div class="borderBot hideHH" id="HzFiltersWrap"><header class="hideHH wide" id="DKFilters"><div class="padVert padHorzMd"><div class="selectContainer"><div class="filter" data-test="JOBTYPE"><span class="label">All Job Types</span><span class="labelArrow"></span></div><div class="filter" data-test="DATEPOSTED"><span class="label">Posted Any Time</span><span class="labelArrow"></span></div><div class="filter" data-test="SALRANGE"><span class="label">$22K - $280K</span><span class="labelArrow"></span></div><div class="filter" data-test="DISTANCE"><span class="label">25 Miles</span><span class="labelArrow"></span></div><div class="filter more expandable"><span class="pointer expandable">More</span><span class="count expandable hidden">(0)</span><span class="labelArrow expandable"></span></div><div class="filter expandable right containerLess createBtnContainer"><a class="gd-btn gd-btn-link gradient gd-btn-2 gd-btn-med large"><span class="SVGInline filterIcons bellIcon outline"><svg class="SVGInline-svg filterIcons-svg bellIcon-svg outline-svg" height="21" viewbox="0 0 18 21" width="18" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M19.51 18.077l-.019-.037c.005.01.01.022.02.037zm-1.163-2.297c-1.243-2.492-1.85-4.698-1.85-7.78 0-2.104-.981-3-2.65-3.523a.5.5 0 0 1-.323-.313 2.238 2.238 0 0 0-.356-.591c-.306-.364-.69-.573-1.182-.573-.491 0-.87.207-1.169.569a2.184 2.184 0 0 0-.346.588.5.5 0 0 1-.323.32C8.474 5.009 7.497 5.9 7.497 8c0 2.887-.579 5.014-1.75 7.413a43.205 43.205 0 0 1-.53 1.05c-.07.135-.119.232-.166.327-.257.508-.426.868-.557 1.193.003-.007.02.017.062.017h14.888c-.184-.462-1.06-2.148-1.097-2.22zM17.497 8c0 2.912.566 4.97 1.745 7.333.026.052.908 1.75 1.144 2.26.365.66-.193 1.407-.943 1.407H4.555c-.723 0-1.232-.699-.997-1.368.151-.379.331-.761.6-1.293a75.088 75.088 0 0 1 .341-.667c.14-.275.246-.486.35-.698C5.958 12.702 6.497 10.72 6.497 8c0-1.485.495-2.607 1.365-3.4.534-.487 1.07-.765 1.759-1.002.093-.201.233-.434.426-.667.477-.576 1.125-.931 1.939-.931.813 0 1.463.354 1.947.928.197.234.34.467.436.668 1.91.655 3.128 1.862 3.128 4.404zM9.04 20h5.918a3 3 0 0 1-5.918 0z" transform="translate(-3,-2)"></path></svg></span>Create Job Alert</a></div></div></div></header></div><div class="module noPad" id="JobResults"><section class="flexbox" id="PanesWrap"><article class="noPad" id="MainCol"><div><div class="hideHH oldStyle" id="MainColSummary"><h1 id="jobTitle">Data engineer Jobs in New York, NY</h1><p class="jobsCount">4,873 Jobs</p></div><ul class="jlGrid hover" id=""><li class="jl selected" data-ad-order-id="487631" data-emp-id="1646026" data-id="3214169303" data-is-easy-apply="false" data-is-organic-job="false" data-job-loc="New York, NY" data-job-loc-id="1132348" data-job-loc-type="C" data-njslv="false" data-normalize-job-title="data consultant" data-purchase-ad-order-id="0" data-sgoc-id="1011"><div class="logoWrap"><a class="jobLink" data-ajax="false" data-ev-a="E-S" data-gd-view="1" data-ja-clk="0" href="/partner/jobListing.htm?pos=101&amp;ao=487631&amp;s=149&amp;guid=0000016afc6dd3d3a95893f780870f43&amp;src=GD_JOB_AD&amp;t=SRFJ&amp;extid=4&amp;exst=OL&amp;ist=&amp;ast=OL&amp;vt=w&amp;slr=true&amp;cs=1_010c56ac&amp;cb=1559013217927&amp;jobListingId=3214169303" rel="nofollow" style="pointer-events: all;" target="_blank"><span class="sqLogo tighten smSqLogo"><img alt="Publicis Sapient Logo" class="lazy lazy-loaded" data-original="https://media.glassdoor.com/sqls/1646026/publicis-sapient-squarelogo-1550022827116.png" data-original-2x="https://media.glassdoor.com/sqlm/1646026/publicis-sapient-squarelogo-1550022827116.png" data-retina-ok="true" src="https://media.glassdoor.com/sqls/1646026/publicis-sapient-squarelogo-1550022827116.png" style="opacity: 1;" title=""/></span></a><span class="compactStars"> 3.6<i class="star"></i></span></div><div><div class="flexbox jobTitle"><div class="titleContainer"><a class="jobLink" data-ajax= ...
# {
#     "@context": "http://schema.org",
#     "@type": "ItemList",
#     "numberOfItems": 27,
#     "itemListElement": [
#
#
#                 {
#                 "@type": "ListItem",
#                 "position": 1,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 2,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 3,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 4,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 5,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 6,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 7,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 8,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 9,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 10,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 11,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 12,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 13,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 14,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 15,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 16,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 17,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 19,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 20,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 21,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 22,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 23,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 24,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 25,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 26,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 27,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 },
#
#                 {
#                 "@type": "ListItem",
#                 "position": 28,
#                 "url": "https://www.glassdoor.com/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm"
#                 }
#     ]
# }
#         </script><div class="tbl fill padHorz margVert" id="ResultsFooter"><div class="cell middle hideMob padVertSm"> Page 1 of 163</div><div class="cell alignRt middle"><div class="pageNavBar noMargBot" id="FooterPageNav"><div class="pagingControls cell middle"><ul><li class="prev"><span class="disabled"><i><span>Previous</span></i></span></li><li class="page current"><span class="disabled">1</span></li><li class="page"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_IP2.htm">2</a></li><li class="page"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_IP3.htm">3</a></li><li class="page"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_IP4.htm">4</a></li><li class="page last"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_IP5.htm">5</a></li><li class="next"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_IP2.htm"><i><span>Next</span></i></a></li></ul></div></div></div></div><div class="borderTop padTop"><div id="InlineJobAlert"><div class="formWrapper"><form autocomplete="off"><div class="JobAlertInlineContainerStyle__microForm___2bYhw"><div class="JobAlertInlineContainerStyle__ctaField___3rMdG JobAlertInlineContainerStyle__ctaFieldInput___eWUSJ"><div class="css-1ohf0ui"><input class="css-yvl55r" maxlength="100" name="email" placeholder="Enter email address" type="email" value="liyingchengcathy@gmail.com"/></div></div><div class="JobAlertInlineContainerStyle__ctaField___3rMdG undefined"><div class="JobAlertInlineContainerStyle__inlineBlock___3yRps"><button class="gd-ui-button common__font14___1Ivfd css-11w9zwm">Create Job Alert</button></div></div></div></form></div></div></div><div class="padBot padLt padRt borderTop padTop" id="AdditionalLinks"><div class="links-group"><div class="refineResults"><div> People Also Searched</div><a href="/Job/new-york-data-scientist-jobs-SRCH_IL.0,8_IC1132348_KO9,23.htm">data scientist</a>, <a href="/Job/new-york-hadoop-jobs-SRCH_IL.0,8_IC1132348_KO9,15.htm">hadoop</a>, <a href="/Job/new-york-data-warehouse-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,32.htm">data warehouse engineer</a>, <a href="/Job/new-york-big-data-jobs-SRCH_IL.0,8_IC1132348_KO9,17.htm">big data</a>, <a href="/Job/new-york-data-mining-jobs-SRCH_IL.0,8_IC1132348_KO9,20.htm">data mining</a>, <a href="/Job/new-york-data-analyst-jobs-SRCH_IL.0,8_IC1132348_KO9,21.htm">data analyst</a>, <a href="/Job/new-york-data-analytics-jobs-SRCH_IL.0,8_IC1132348_KO9,23.htm">data analytics</a>, <a href="/Job/new-york-software-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,26.htm">software engineer</a>, <a href="/Job/new-york-business-intelligence-jobs-SRCH_IL.0,8_IC1132348_KO9,30.htm">business intelligence</a>, <a href="/Job/new-york-etl-jobs-SRCH_IL.0,8_IC1132348_KO9,12.htm">etl</a></div></div><div class="links-group"><div class="links-label"> Top Cities for data engineer:  </div><div class="links"><a href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22.htm">New York</a>, <a href="/Job/jersey-city-data-engineer-jobs-SRCH_IL.0,11_IC1126819_KO12,25.htm">Jersey City</a>, <a href="/Job/brooklyn-data-engineer-jobs-SRCH_IL.0,8_IC1132200_KO9,22.htm">Brooklyn</a>, <a href="/Job/newark-data-engineer-jobs-SRCH_IL.0,6_IC1126906_KO7,20.htm">Newark</a>, <a href="/Job/parsippany-data-engineer-jobs-SRCH_IL.0,10_IC1126931_KO11,24.htm">Parsippany</a>, <a href="/Job/hoboken-data-engineer-jobs-SRCH_IL.0,7_IC1126809_KO8,21.htm">Hoboken</a>, <a href="/Job/florham-park-data-engineer-jobs-SRCH_IL.0,12_IC1126766_KO13,26.htm">Florham Park</a>, <a href="/Job/franklin-lakes-data-engineer-jobs-SRCH_IL.0,14_IC1157325_KO15,28.htm">Franklin Lakes</a>, <a href="/Job/iselin-data-engineer-jobs-SRCH_IL.0,6_IC1126816_KO7,20.htm">Iselin</a>, <a href="/Job/englewood-cliffs-data-engineer-jobs-SRCH_IL.0,16_IC1126753_KO17,30.htm">Englewood Cliffs</a></div></div><div class="links-group"><div class="links-label"> Top Companies for data engineer in New York, NY:  </div ...
# <div>
# Apply Now</div>
# </div>
# </div>
# </div>
# <br/></div></div></div></div></div><div class="jobDetailsFooter padVertSm newCtaLayout"><div><div class="breadcrumb ib" itemprop="" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a class="minorLink" href="/Job/index.htm" itemprop="url"><span itemprop="title">Jobs</span><span> &gt; </span></a></div><div class="breadcrumb ib" itemprop="child" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a class="minorLink" href="/Job/data-engineer-jobs-SRCH_KO0,13_SAMV.htm" itemprop="url"><span itemprop="title">data engineer</span><span> &gt; </span></a></div><div class="breadcrumb ib" itemprop="child" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a class="minorLink" href="/Job/new-york-data-engineer-jobs-SRCH_IL.0,8_IC1132348_KO9,22_SAMV.htm" itemprop="url"><span itemprop="title">New York</span></a></div></div><div><a class="minorLink showDataTableBtn margRtSm">View Data as Table</a><div class="reportJobFormWrapper"><a class="minorLink showReportJobForm">Report this job</a></div></div></div></div></div></article></div></div></section></div></div></div><iframe id="JobSearchAsyncClickTrackingFrame" src="/job-listing/trackClickAsync.htm?pos=101&amp;ao=487631&amp;s=149&amp;guid=0000016afc6dd3d3a95893f780870f43&amp;src=GD_JOB_AD&amp;t=SRFJ&amp;extid=4&amp;exst=OL&amp;ist=&amp;ast=OL&amp;vt=w&amp;slr=true&amp;cs=1_010c56ac&amp;cb=1559013217927&amp;jobListingId=3214169303&amp;tgt=GD_PANE_VIEW&amp;uco=serp-job-listings-click&amp;rd=true" style="display:none;"></iframe><div class="dialogBody hidden jobAlertDlgBody jobAlertDlgSrc jobAlertDlgScreenshot noMargBot noPadBot padTopLg"><div class="cf"><h2 class="heading middle ib tightVert"> Email me jobs for:</h2></div><div class="dialogContent"><div class="center margBot30 margTop15 cf hidden alertConfirm"><p class="alertMsg margTop30 margBot30 h3">Your Job Alert was created!</p><p class="h4 margTop10">Taking you to the job you clicked earlier...</p></div><form class="" name="createJobAlertForm"><div class="closeable ajaxResult margTopSm" id="CompletedAction"><p class="headline"></p><div class="clear"></div></div><div class="tbl" id="WebmailConfirm"><div class="icon-wrapper cell middle"></div><div class="link-wrapper cell middle margLt"></div></div><div class="formContents fill"><div class="value jobAlertCompanyWrapper cf"><label class="forcedHidden" for="jobAlertCompany">Enter company</label><input class="std job-alert-company jobAlertCompany floatLt margRt10 med fill margTop" id="jobAlertCompany" maxlength="200" name="company" placeholder="Enter company" type="text" value=""/></div><div class="value jobAlertKeyWrapper margTop"><label class="forcedHidden" for="jobAlertTitle">Enter job title</label><span class="phrase"></span><span class="link margLt10">edit</span><input class="std job-alert-keyword required jobAlertKeyword floatLt margRt10 med fill" id="jobAlertTitle" maxlength="200" name="keyword" placeholder="Enter job title" type="text" value=""/></div><div class="jobAlertLocWrapper hidden margTop"><div class="value jobAlertLocWrapper"><label class="forcedHidden" for="jobAlertLocation">Enter location</label><input class="std job-alert-location required jobAlertLocation floatLt margRt10 med fill margTop" id="jobAlertLocation" maxlength="200" name="location" placeholder="Enter location" type="text" value=""/></div><div class="clear"></div></div><div class="jobAlertEmailWrapper margTop"><div class="value"><label class="forcedHidden" for="jobAlertEmail">Enter your email address</label><input class="std job-alert-email required jobAlertUserEmail floatLt margRt10 med fill" id="jobAlertEmail" maxlength="200" name="emailAddress" placeholder="Enter your email address" type="text" value="liyingchengcathy@gmail.com"/></div><div class="clear"></div></div><div class="margTop alignRt"><button class="ib createJobAlert gd-btn gd-btn-submit gd-btn-1 gd-btn-med gradient" type="submit"><span>Create Alert</span><i class="hlpr"></i></button></div><input class="jobAlertUrl" n ...
#         GD.perf.mark(GD.perf.MARK_PERCEIVED_LOAD);
#     </script><div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div><iframe allow="encrypted-media" allowfullscreen="true" allowtransparency="true" aria-hidden="true" frameborder="0" id="fb_xdm_frame_https" name="fb_xdm_frame_https" scrolling="no" src="https://staticxx.facebook.com/connect/xd_arbiter.php?version=44#channel=f2a35fb94e023d&amp;origin=https%3A%2F%2Fwww.glassdoor.com" style="border: none;" tabindex="-1" title="Facebook Cross Domain Communication Frame"></iframe></div><div></div></div></div><script>
#     window.GD.page = window.GD.page || {};
#
# ...
# <script id="" src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script><script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script><div id="batBeacon0.7979929548420286" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.07836068577425559" src="https://bat.bing.com/action/0?ti=5422570&amp;Ver=2&amp;mid=df771fac-1862-cbf4-5e6e-f97012e9cb1e&amp;pi=1200101525&amp;lg=en-US&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Data%20engineer%20Jobs%20in%20New%20York,%20NY%20%7C%20Glassdoor&amp;p=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;r=https%3A%2F%2Fwww.glassdoor.com%2F&amp;lt=4493&amp;evt=pageLoad&amp;msclkid=N&amp;rn=616413" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div>
# <script id="" type="text/javascript">bk_addPageCtx("siteSection","Search-Jobs");bk_addPageCtx("age","");bk_addPageCtx("gender","UNKNOWN");bk_addPageCtx("education","");bk_addPageCtx("memberType","BASIC");bk_addPageCtx("source","undefined");bk_addPageCtx("sourceType","undefined");bk_addPageCtx("employerSize","");bk_addPageCtx("employerIndustry","undefined");bk_addPageCtx("jobCategory","10041");
# bk_addPageCtx("salarySurveyJobTitle","undefined");bk_addPageCtx("salarySurveyJobTitleId","undefined");bk_addPageCtx("interviewSurveyJobTitle","undefined");bk_addPageCtx("interviewSurveyJobTitleId","undefined");bk_addPageCtx("kwyiJobTitle","undefined");bk_addPageCtx("kwyiJobTitleId","undefined");bk_addPageCtx("kwyiSalary","undefined");bk_addPageCtx("SGOC","undefined");bk_addPageCtx("MGOC","undefined");
# bk_addPageCtx("siteSectionSGOC","Search-Jobs::undefined");bk_addPageCtx("siteSectionMGOC","Search-Jobs::undefined");bk_doJSTag(24270,15);</script>
# <iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=1naj8dws;ord=8814131284453;gtm=2wg5f2;auiddc=832984568.1559011948;u1=1646026;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=evg2uxl0;ord=8410775031592;gtm=2wg5f2;auiddc=832984568.1559011948;u2=1646026;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><script id="" type="text/javascript">window.criteo_q=window.criteo_q||[];var deviceType=/iPad/.test(navigator.userAgent)?"t":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent)?"m":"d";
# window.criteo_q.push({event:"manualFlush"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"setEmail",email:"user_email"},{event:"viewItem",item:"3225091001"},{event:"flushEvents"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"viewItem",item:"1"},{event:"flushEvents"});</script><script id="" type="text/javascript">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"5422570"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><noscript><img height="0" src="//bat.bing.com/action/0?ti=5422570&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/></noscript><iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script id="" src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script><script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script><div id="batBeacon0.2124883146514287" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.08707688544915948" src="https://bat.bing.com/action/0?ti=5422570&amp;Ver=2&amp;mid=367c3266-8f9a-5f63-48f8-34ace0cefbb1&amp;pi=1200101525&amp;lg=en-US&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Data%20engineer%20Jobs%20in%20New%20York,%20NY%20%7C%20Glassdoor&amp;p=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;r=https%3A%2F%2Fwww.glassdoor.com%2F&amp;lt=4493&amp;evt=pageLoad&amp;msclkid=N&amp;rn=446796" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div>
# <script id="" type="text/javascript">bk_addPageCtx("siteSection","Search-Jobs");bk_addPageCtx("age","");bk_addPageCtx("gender","UNKNOWN");bk_addPageCtx("education","");bk_addPageCtx("memberType","BASIC");bk_addPageCtx("source","undefined");bk_addPageCtx("sourceType","undefined");bk_addPageCtx("employerSize","");bk_addPageCtx("employerIndustry","undefined");bk_addPageCtx("jobCategory","10143");
# bk_addPageCtx("salarySurveyJobTitle","undefined");bk_addPageCtx("salarySurveyJobTitleId","undefined");bk_addPageCtx("interviewSurveyJobTitle","undefined");bk_addPageCtx("interviewSurveyJobTitleId","undefined");bk_addPageCtx("kwyiJobTitle","undefined");bk_addPageCtx("kwyiJobTitleId","undefined");bk_addPageCtx("kwyiSalary","undefined");bk_addPageCtx("SGOC","undefined");bk_addPageCtx("MGOC","undefined");
# bk_addPageCtx("siteSectionSGOC","Search-Jobs::undefined");bk_addPageCtx("siteSectionMGOC","Search-Jobs::undefined");bk_doJSTag(24270,15);</script>
# <script id="" type="text/javascript">window.criteo_q=window.criteo_q||[];var deviceType=/iPad/.test(navigator.userAgent)?"t":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent)?"m":"d";
# window.criteo_q.push({event:"manualFlush"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"setEmail",email:"user_email"},{event:"viewItem",item:"3214169303"},{event:"flushEvents"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"viewItem",item:"1"},{event:"flushEvents"});</script><iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=1naj8dws;ord=1551869379656;gtm=2wg5f2;auiddc=832984568.1559011948;u1=369261;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=evg2uxl0;ord=3163920166030;gtm=2wg5f2;auiddc=832984568.1559011948;u2=369261;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><img alt="" border="0" height="1" id="PixelXSP" src="https://pubads.g.doubleclick.net/activity;xsp=4360481;ord=9066466706044.236?" width="1"/><script id="" type="text/javascript">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"5422570"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><noscript><img height="0" src="//bat.bing.com/action/0?ti=5422570&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/></noscript><iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script id="" src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script><script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script><div id="batBeacon0.35549089576845905" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.9455628185297227" src="https://bat.bing.com/action/0?ti=5422570&amp;Ver=2&amp;mid=3cdfc550-6951-cadf-486b-443ce54f7be2&amp;pi=1200101525&amp;lg=en-US&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Data%20engineer%20Jobs%20in%20New%20York,%20NY%20%7C%20Glassdoor&amp;p=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;r=https%3A%2F%2Fwww.glassdoor.com%2F&amp;lt=4493&amp;evt=pageLoad&amp;msclkid=N&amp;rn=379803" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div>
# <script id="" type="text/javascript">bk_addPageCtx("siteSection","Search-Jobs");bk_addPageCtx("age","");bk_addPageCtx("gender","UNKNOWN");bk_addPageCtx("education","");bk_addPageCtx("memberType","BASIC");bk_addPageCtx("source","undefined");bk_addPageCtx("sourceType","undefined");bk_addPageCtx("employerSize","");bk_addPageCtx("employerIndustry","undefined");bk_addPageCtx("jobCategory","10041");
# bk_addPageCtx("salarySurveyJobTitle","undefined");bk_addPageCtx("salarySurveyJobTitleId","undefined");bk_addPageCtx("interviewSurveyJobTitle","undefined");bk_addPageCtx("interviewSurveyJobTitleId","undefined");bk_addPageCtx("kwyiJobTitle","undefined");bk_addPageCtx("kwyiJobTitleId","undefined");bk_addPageCtx("kwyiSalary","undefined");bk_addPageCtx("SGOC","undefined");bk_addPageCtx("MGOC","undefined");
# bk_addPageCtx("siteSectionSGOC","Search-Jobs::undefined");bk_addPageCtx("siteSectionMGOC","Search-Jobs::undefined");bk_doJSTag(24270,15);</script>
# <iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=1naj8dws;ord=5086645225170;gtm=2wg5f2;auiddc=832984568.1559011948;u1=1646026;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><iframe height="0" src="//5820279.fls.doubleclick.net/activityi;src=5820279;type=invmedia;cat=evg2uxl0;ord=3147721007045;gtm=2wg5f2;auiddc=832984568.1559011948;u2=1646026;~oref=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm?" style="display: none; visibility: hidden;" width="0"></iframe><script id="" type="text/javascript">window.criteo_q=window.criteo_q||[];var deviceType=/iPad/.test(navigator.userAgent)?"t":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent)?"m":"d";
# window.criteo_q.push({event:"manualFlush"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"setEmail",email:"user_email"},{event:"viewItem",item:"3225091001"},{event:"flushEvents"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"viewItem",item:"1"},{event:"flushEvents"});</script><script id="" type="text/javascript">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"5422570"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><noscript><img height="0" src="//bat.bing.com/action/0?ti=5422570&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/></noscript><iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script id="" src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script><script id="" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script><div id="batBeacon0.30232595681425" style="width:0px; height:0px; display:none; visibility:hidden;"><img alt="" height="0" id="batBeacon0.3130792825325346" src="https://bat.bing.com/action/0?ti=5422570&amp;Ver=2&amp;mid=bee5ceb8-b71e-85a1-b18c-64feff7e4284&amp;pi=1200101525&amp;lg=en-US&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Data%20engineer%20Jobs%20in%20New%20York,%20NY%20%7C%20Glassdoor&amp;p=https%3A%2F%2Fwww.glassdoor.com%2FJob%2Fnew-york-data-engineer-jobs-SRCH_IL.0%2C8_IC1132348_KO9%2C22.htm&amp;r=https%3A%2F%2Fwww.glassdoor.com%2F&amp;lt=4493&amp;evt=pageLoad&amp;msclkid=N&amp;rn=167011" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/></div>
# <script id="" type="text/javascript">bk_addPageCtx("siteSection","Search-Jobs");bk_addPageCtx("age","");bk_addPageCtx("gender","UNKNOWN");bk_addPageCtx("education","");bk_addPageCtx("memberType","BASIC");bk_addPageCtx("source","undefined");bk_addPageCtx("sourceType","undefined");bk_addPageCtx("employerSize","");bk_addPageCtx("employerIndustry","undefined");bk_addPageCtx("jobCategory","10143");
# bk_addPageCtx("salarySurveyJobTitle","undefined");bk_addPageCtx("salarySurveyJobTitleId","undefined");bk_addPageCtx("interviewSurveyJobTitle","undefined");bk_addPageCtx("interviewSurveyJobTitleId","undefined");bk_addPageCtx("kwyiJobTitle","undefined");bk_addPageCtx("kwyiJobTitleId","undefined");bk_addPageCtx("kwyiSalary","undefined");bk_addPageCtx("SGOC","undefined");bk_addPageCtx("MGOC","undefined");
# bk_addPageCtx("siteSectionSGOC","Search-Jobs::undefined");bk_addPageCtx("siteSectionMGOC","Search-Jobs::undefined");bk_doJSTag(24270,15);</script>
# <script id="" type="text/javascript">window.criteo_q=window.criteo_q||[];var deviceType=/iPad/.test(navigator.userAgent)?"t":/Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test(navigator.userAgent)?"m":"d";
# window.criteo_q.push({event:"manualFlush"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"setEmail",email:"user_email"},{event:"viewItem",item:"3214169303"},{event:"flushEvents"},{event:"setAccount",account:48243},{event:"setSiteType",type:deviceType},{event:"viewItem",item:"1"},{event:"flushEvents"});</script><script defer="" src="https://www.glassdoor.com/jobs-ux-app/static/js/dist/gd-emp-photo-slider.bundle.js"></script><div id="PhotosliderWrap"><div id="photoslider-closed" style="display: none;"></div></div></body></html>
